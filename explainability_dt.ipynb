# %% [markdown]
# <a href="https://colab.research.google.com/github/iman-saleh/ethical-ai/blob/master/explainability_dt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This code is based on [scikit-learn decision tree sample code](https://scikit-learn.org/stable/modules/tree.html)

# %%
#Example 1: Iris dataset

import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
features=iris.feature_names 
df=pd.DataFrame(iris.data, columns=features)
y=iris.target
target_names = iris.target_names

# %%
#Example 2: Breast Cancer Dataset

# Now try to generate a similar decision tree visualization for the scikit learn breast cancer dataset
# Hint: dataset can be loaded using datasets.load_breast_cancer()
#Example 2: Breast cancer dataset

import sklearn.datasets as datasets
import pandas as pd
bc=datasets.load_breast_cancer()
features=bc.feature_names 
df=pd.DataFrame(bc.data, columns=features)
y=bc.target
target_names = bc.target_names

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, 
                feature_names=features,
                class_names=target_names)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
